# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_hdf("../simulation_measurement_comparison/simulated_and_measured.h5", key="data_fixed_uncert_with_co2e")
data
# Out:
#    diluent  phi_nom  dil_mf_nom            p_0     u_p_0         t_0  \
# 0      CO2      0.4        0.10  101393.842884  2.307000  289.846188
# 1      CO2      0.4        0.15  101400.200470  1.609842  290.021614
# 2      CO2      0.4        0.20  101383.316513  1.976709  290.005443
# 3      CO2      0.7        0.10  101393.617108  2.121143  289.767941
# 4      CO2      0.7        0.15  101412.528953  2.179424  289.308769
# 5      CO2      0.7        0.20  101412.244820  1.938748  290.890143
# 6      CO2      1.0        0.10  101396.288279  2.719599  290.170199
# 7      CO2      1.0        0.15  101404.272743  1.800340  290.141360
# 8      CO2      1.0        0.20  101410.128009  1.557379  290.441929
# 9       N2      0.4        0.10  101368.606788  2.121188  289.359526
# 10      N2      0.4        0.15  101402.450299  2.548703  289.162940
# 11      N2      0.7        0.10  101356.652110  1.771724  289.671173
# 12      N2      0.7        0.15  101372.880235  2.368101  289.048889
# ...

# %%
data["ratio"] = data["cell_size_westbrook"] / data["cell_size_measured"]

# %%
sns.relplot(x="phi", y="ratio", col="dil_mf_nom", hue="diluent", data=data)

# %%
data.groupby("diluent")["ratio"].mean()
# Out:
# diluent
# CO2    2.759174
# N2     1.435012
# Name: ratio, dtype: float64
